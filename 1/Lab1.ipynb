# %% [markdown]
# # Первичный анализ и предобработка данных с Pandas

# %% [markdown]
# _Комлева Юлия РИМ-181226_

# %% [markdown]
# В этом задании рассмотрим первичный анализ данных на примере реальных данных по шоколадным батончикам. Данные содержат следующие атрибуты: 'company' - компания производитель, 'bar_name' - название шоколадного батончика, 'ref' - номер, 'rew_date' - дата оценки, 'percent' - процент какао бобов, 'company_loc' - местонахождение компании, 'rate' - рейтинг, 'bean_dtype' - тип какао бобов, 'bean_orig' - страна происхождения.

# %% [markdown]
# ## Численные атрибуты

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
best_bar= pd.read_csv('flavors_of_cacao.csv',
                       sep=',', header=0, names=['company', 'bar_name','ref', 'rew_date', 'percent', 'company_loc', 'rate', 'bean_dtype', 'bean_orig'])

# %%
type(best_bar)
# Out:
# pandas.core.frame.DataFrame

# %%
best_bar.shape
# Out:
# (1795, 9)

# %% [markdown]
# Оставим только только местонахождение компании, рейтинг, процент какао бобов и страну происхождения для дальнейшего анализа.

# %%
best_bar = best_bar[['company_loc', 'rate', 'percent', 'bean_orig']]
best_bar.head()
# Out:
#   company_loc  rate percent bean_orig
# 0      France  3.75     63%  Sao Tome
# 1      France  2.75     70%      Togo
# 2      France  3.00     70%      Togo
# 3      France  3.50     70%      Togo
# 4      France  3.50     70%      Peru

# %%
best_bar.shape
# Out:
# (1795, 4)

# %% [markdown]
# Необходимо построить гистограмму распределения рейтинга батончика через plot(). Количество столбцов гистограммы равно 20.
# На одном графике необходимо построить график плотности вероятности, который строится на основе оценки непрерывного распределения вероятности. Гистограммы аппроксимируют комбинацией ядре, т.е. более простых распределений, например нормалього (гауссова). Поэтому графики плотности еще называют ядерной окенки плотности (KDE-kernel density estimate). Строится kde с помощью функции плот с параметром kind='kde'.

# %%
ax = best_bar.rate.plot(kind='hist', bins=20)
best_bar.rate.plot(kind = 'kde', ax=ax, secondary_y=True)
#best_bar.rate.plot(kind ='kde').hist(best_bar.rate, bins = 20)

# %% [markdown]
# Необходимо построить гистограмму распределения для процента какао бобов. Однако, следует отметить, что данные атрибут имеет тип object. Шистограмму для такого типа построить не получиться.

# %%
best_bar.percent.head()
# Out:
# 0    63%
# 1    70%
# 2    70%
# 3    70%
# 4    70%
# Name: percent, dtype: object

# %% [markdown]
# Необходимо преобразовать данный тип в float с помощью функции apply. Причем сначала необходимо убрать знак '%' в конце каждого элемента, а затем преобразовать в тип данных с плавающей точкой. Функция apply проходит по всем значениям данных и применяет указанную функцию.

# %%
best_bar.percent = best_bar.percent.apply(lambda x: float(x.rstrip("%")))
best_bar.head()
# Out:
#   company_loc  rate  percent bean_orig
# 0      France  3.75     63.0  Sao Tome
# 1      France  2.75     70.0      Togo
# 2      France  3.00     70.0      Togo
# 3      France  3.50     70.0      Togo
# 4      France  3.50     70.0      Peru

# %%
ax = best_bar.percent.plot(kind='hist', bins=20)
best_bar.percent.plot(kind = 'kde', ax=ax, secondary_y=True)

# %% [markdown]
# Постройте scatter plot зависимости рейтинга батончика от процента какао бобов, используя метод plot для Pandas DataFrame с аргументом kind='scatter'. Подпишите картинку.

# %%
best_bar.plot(x = 'rate', y = 'percent', kind = "scatter", title = "Зависимость рейтинга от содержания какао бобов")

# %% [markdown]
# Постройте "ящик с усами" для числовых распределений с помощью функции boxplot. Возпользуйтесь также функцией describe() для каждого распределения.

# %%
# code here
best_bar.boxplot()

# %%
best_bar.describe()
# Out:
#               rate      percent
# count  1795.000000  1795.000000
# mean      3.185933    71.698329
# std       0.478062     6.323118
# min       1.000000    42.000000
# 25%       2.875000    70.000000
# 50%       3.250000    70.000000
# 75%       3.500000    75.000000
# max       5.000000   100.000000

# %%
#best_bar.rate.plot.box()
#best_bar.rate.boxplot() -> AttributeError: 'Series' object has no attribute 'boxplot'
#best_bar['rate'].boxplot() -> AttributeError: 'Series' object has no attribute 'boxplot'
best_bar[['rate']].boxplot()

# %%
best_bar.percent.plot.box()

# %% [markdown]
# ## Категориальные атрибуты

# %% [markdown]
# Обратим внимание на категориальные признаки. Построить гистограмму распределения не удасться, но в качестве начального анализа можно воспользоваться функцией value_counts, которая позволяет вывести количество встречающихся значений в атрибуте данных. Обратите внимание внимание на места происхождения бобов, которые редко встречаются в наборе данных. Для вывода начальных и конечных элементов используются функции head() и tail() соответственно.

# %%
best_bar.bean_orig.value_counts().head()
# Out:
# Venezuela             214
# Ecuador               193
# Peru                  165
# Madagascar            145
# Dominican Republic    141
# Name: bean_orig, dtype: int64

# %%
best_bar.bean_orig.value_counts().tail()
# Out:
# Peru, Ecuador               1
# Peru, Ecuador, Venezuela    1
# Venezuela, Dom. Rep.        1
# Suriname                    1
# Ghana & Madagascar          1
# Name: bean_orig, dtype: int64

# %% [markdown]
# После того, как выведено количество уникальных значений можно представить их визуальное распределение с помощью функции plot(kind='bar').

# %%
# code here
best_bar.company_loc.value_counts().plot(kind = 'bar', figsize = (15, 5), title = "company_loc")
# figsize : a tuple (width, height) in inches

# %%
best_bar.bean_orig.value_counts().plot(kind = 'bar', figsize = (20, 5), title = 'bean_orig')

# %% [markdown]
# По гистограмме распределения категориальных атрибутов о происхождения какао бобов можно увидеть, что присутствует хаос в данных. Для некоторых объектов названия мест происхождения написаны с ошибками, у некоторых объектов вообще отсутствует место происхождения, а так же есть батончики, состоящие из какао бобов из разных мест происхождения. В этой связи необходимо произвести предобработку данных для дальнейшего анализа.
# Для начала убрать объекты с пропущенными записями, используя функцию dropna. Необходимо отметить, что в качестве параметров функции передается 'axis', где 0 - удалять по строкам (объектам), 1 - удалять по столбцам, 'how', где 'any' - удалять строку или столбец, если есть пустой объект, 'all' - удалять строку или столбец, если все объекты пустые.

# %%
best_bar = best_bar.dropna(axis = 0) #dropna(0,'any')
best_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1794 entries, 0 to 1794
# Data columns (total 4 columns):
# company_loc    1794 non-null object
# rate           1794 non-null float64
# percent        1794 non-null float64
# bean_orig      1794 non-null object
# dtypes: float64(2), object(2)
# memory usage: 70.1+ KB

# %% [markdown]
# Заметим, что пустые записи из атрибута происхождения бобов не удалилсь. Значит "пустые" записи не являются пустыми. Выведите все уникальные значения атрибута 'bean_orig' с помощью функции unique() и найдите значение пустой записи.

# %%
best_bar.bean_orig.unique()
#'\xa0'
# Out:
# array(['Sao Tome', 'Togo', 'Peru', 'Venezuela', 'Cuba', 'Panama',
#        'Madagascar', 'Brazil', 'Ecuador', 'Colombia', 'Burma',
#        'Papua New Guinea', 'Bolivia', 'Fiji', 'Mexico', 'Indonesia',
#        'Trinidad', 'Vietnam', 'Nicaragua', 'Tanzania',
#        'Dominican Republic', 'Ghana', 'Belize', '\xa0', 'Jamaica',
#        'Grenada', 'Guatemala', 'Honduras', 'Costa Rica',
#        'Domincan Republic', 'Haiti', 'Congo', 'Philippines', 'Malaysia',
#        'Dominican Rep., Bali', 'Venez,Africa,Brasil,Peru,Mex', 'Gabon',
#        'Ivory Coast', 'Carribean', 'Sri Lanka', 'Puerto Rico', 'Uganda',
#        'Martinique', 'Sao Tome & Principe', 'Vanuatu', 'Australia',
#        'Liberia', 'Ecuador, Costa Rica', 'West Africa', 'Hawaii',
#        'St. Lucia', 'Cost Rica, Ven', 'Peru, Madagascar',
#        'Venezuela, Trinidad', 'Trinidad, Tobago',
#        'Ven, Trinidad, Ecuador', 'South America, Africa', 'India',
#        'Africa, Carribean, C. Am.', 'Tobago', 'Ven., Indonesia, Ecuad.',
#        'Trinidad-Tobago', 'Peru, Ecuador, Venezuela',
#        'Venezuela, Dom. Rep.', 'Colombia, Ecuador', 'Solomon Islands',
#        'Nigeria', 'Peru, Belize', 'Peru, Mad., Dom. Rep.',
#        'PNG, Vanuatu, Mad', 'El Salvador', 'South America', 'Samoa',
#        'Ghana, Domin. Rep', 'Trinidad, Ecuador', 'Cameroon',
#        'Venezuela, Java', 'Venezuela/ Ghana', 'Venezuela, Ghana',
#        'Indonesia, Ghana', 'Peru(SMartin,Pangoa,nacional)', 'Principe',
#        'Central and S. America', 'Ven., Trinidad, Mad.',
#        'Carribean(DR/Jam/Tri)', 'Ghana & Madagascar',
#        'Ven.,Ecu.,Peru,Nic.', 'Madagascar & Ecuador',
#        'Guat., D.R., Peru, Mad., PNG', 'Peru, Dom. Rep',
#        'Dom. Rep., Madagascar', 'Gre., PNG, Haw., Haiti, Mad',
#        'Mad., Java, PNG', 'Ven, Bolivia, D.R.', 'DR, Ecuador, Peru',
#        'Suriname', 'Peru, Ecuador', 'Ecuador, Mad., PNG',
#        'Ghana, Panama, Ecuador', 'Venezuela, Carribean'], dtype=object)

# %% [markdown]
# Для того, чтобы исключить данный элемент, необходимо использовать слудующую конструкцию: best_bar['bean_orig'] != 'element value', которая вернет бинарный массив элементов, где True - атрибут объекта не принимает значение 'element value', False - атрибут объекта принимает значение 'element value'. Затем полученную бинарную матрицу передаем в качестве маски, по которой будут выбраны объекты из нашего массива данных.

# %%
#best_bar.bean_orig[1789]
#best_bar['bean_orig'] != '\xa0'
best_bar = best_bar[best_bar['bean_orig'] != '\xa0']
#best_bar['bean_orig']=best_bar.loc[best_bar['bean_orig']!='\xa0']

# %%
best_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1721 entries, 0 to 1794
# Data columns (total 4 columns):
# company_loc    1721 non-null object
# rate           1721 non-null float64
# percent        1721 non-null float64
# bean_orig      1721 non-null object
# dtypes: float64(2), object(2)
# memory usage: 67.2+ KB

# %% [markdown]
# Помимо этого необходимо решить проблему с батончиками из разных какао бобов. Лучшим способом является обработка и разделение этих составных бобов. Но на данном этапе, в виду их малого вклада, мы уберем их и сделаем одним видом сложного состава 'complex'. Будем считать редковстречающимися, если в выборке их не более 5.

# %%
#best_bar.bean_orig.apply(lambda q: q.find(","))
#mask = best_bar.bean_orig.apply(lambda q: "," in q or "/" in q or "&" in q )
#best_bar.loc[mask, 'bean_orig'] = "complex"

# %%
best_bar.bean_orig.unique()
# Out:
# array(['Sao Tome', 'Togo', 'Peru', 'Venezuela', 'Cuba', 'Panama',
#        'Madagascar', 'Brazil', 'Ecuador', 'Colombia', 'Burma',
#        'Papua New Guinea', 'Bolivia', 'Fiji', 'Mexico', 'Indonesia',
#        'Trinidad', 'Vietnam', 'Nicaragua', 'Tanzania',
#        'Dominican Republic', 'Ghana', 'Belize', 'Jamaica', 'Grenada',
#        'Guatemala', 'Honduras', 'Costa Rica', 'Domincan Republic',
#        'Haiti', 'Congo', 'Philippines', 'Malaysia',
#        'Dominican Rep., Bali', 'Venez,Africa,Brasil,Peru,Mex', 'Gabon',
#        'Ivory Coast', 'Carribean', 'Sri Lanka', 'Puerto Rico', 'Uganda',
#        'Martinique', 'Sao Tome & Principe', 'Vanuatu', 'Australia',
#        'Liberia', 'Ecuador, Costa Rica', 'West Africa', 'Hawaii',
#        'St. Lucia', 'Cost Rica, Ven', 'Peru, Madagascar',
#        'Venezuela, Trinidad', 'Trinidad, Tobago',
#        'Ven, Trinidad, Ecuador', 'South America, Africa', 'India',
#        'Africa, Carribean, C. Am.', 'Tobago', 'Ven., Indonesia, Ecuad.',
#        'Trinidad-Tobago', 'Peru, Ecuador, Venezuela',
#        'Venezuela, Dom. Rep.', 'Colombia, Ecuador', 'Solomon Islands',
#        'Nigeria', 'Peru, Belize', 'Peru, Mad., Dom. Rep.',
#        'PNG, Vanuatu, Mad', 'El Salvador', 'South America', 'Samoa',
#        'Ghana, Domin. Rep', 'Trinidad, Ecuador', 'Cameroon',
#        'Venezuela, Java', 'Venezuela/ Ghana', 'Venezuela, Ghana',
#        'Indonesia, Ghana', 'Peru(SMartin,Pangoa,nacional)', 'Principe',
#        'Central and S. America', 'Ven., Trinidad, Mad.',
#        'Carribean(DR/Jam/Tri)', 'Ghana & Madagascar',
#        'Ven.,Ecu.,Peru,Nic.', 'Madagascar & Ecuador',
#        'Guat., D.R., Peru, Mad., PNG', 'Peru, Dom. Rep',
#        'Dom. Rep., Madagascar', 'Gre., PNG, Haw., Haiti, Mad',
#        'Mad., Java, PNG', 'Ven, Bolivia, D.R.', 'DR, Ecuador, Peru',
#        'Suriname', 'Peru, Ecuador', 'Ecuador, Mad., PNG',
#        'Ghana, Panama, Ecuador', 'Venezuela, Carribean'], dtype=object)

# %%
best_bar = best_bar.loc[(best_bar.bean_orig.value_counts() <= 5).values]
best_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 36 to 102
# Data columns (total 4 columns):
# company_loc    63 non-null object
# rate           63 non-null float64
# percent        63 non-null float64
# bean_orig      63 non-null object
# dtypes: float64(2), object(2)
# memory usage: 2.5+ KB

# %%
best_bar.bean_orig.unique()
# Out:
# array(['Vietnam', 'Madagascar', 'Venezuela', 'Peru', 'Ecuador',
#        'Nicaragua', 'Tanzania', 'Bolivia', 'Dominican Republic',
#        'Papua New Guinea', 'Indonesia', 'Ghana', 'Belize', 'Jamaica',
#        'Grenada', 'Trinidad', 'Brazil', 'Mexico'], dtype=object)

# %% [markdown]
# Постройте круговую гистограмму распределения для стран происзводителей какао бобов с помощью функции pie().

# %%
# code here
#best_bar.company_loc.plot.pie()
#best_bar.company_loc.value_counts().plot(kind='pie', title = 'Number of appearances in dataset', figsize = (15, 15),)
best_bar.bean_orig.value_counts().plot(kind='pie', title = 'Number of appearances in dataset', figsize = (15, 15),)
#plt.axis('equal')

# %% [markdown]
# ## Попарные графики распределений

# %%
from sklearn import preprocessing
from seaborn import pairplot

# %% [markdown]
# Построить попарные распределения для всех признаков.

# %%
# code here
best_bar.company_loc = best_bar.company_loc.astype('category')
best_bar.bean_orig = best_bar.bean_orig.astype('category')
best_bar.company_loc_code=best_bar.company_loc.cat.codes
best_bar.bean_orig_code=best_bar.bean_orig.cat.codes
pairplot(best_bar)
##Categoricals are a pandas data type corresponding to categorical variables in statistics.
#all columns in an existing DataFrame can be batch converted using DataFrame.astype():

# %%
best_bar.head
# Out:
# <bound method NDFrame.head of      company_loc  rate  percent           bean_orig  company_loc_code  \
# 36        France  2.75     75.0             Vietnam                 2
# 37        France  3.00     75.0          Madagascar                 2
# 38        France  2.50     75.0           Venezuela                 2
# 39        France  2.50     75.0                Peru                 2
# 40   Netherlands  3.50     70.0             Ecuador                 4
# 41   Netherlands  3.50     70.0           Nicaragua                 4
# 42   Netherlands  3.50     70.0             Vietnam                 4
# 43   Netherlands  3.50     70.0            Tanzania                 4
# 44        U.S.A.  2.75     60.0           Nicaragua                 7
# 45        U.S.A.  3.00     60.0                Peru                 7
# 46        U.S.A.  2.50     60.0             Bolivia                 7
# 47        U.S.A.  2.50     60.0                Peru                 7
# 48        U.S.A.  2.75     60.0             Ecuador                 7
# 49        U.S.A.  2.50     60.0           Venezuela                 7
# 50        U.S.A.  3.00     60.0  Dominican Republic                 7
# 51        U.S.A.  3.25     80.0             Bolivia                 7
# 52        U.S.A.  3.00     60.0             Bolivia                 7
# 53        U.S.A.  3.25     60.0                Peru                 7
# 54        U.S.A.  4.00     70.0    Papua New Guinea                 7
# 55        U.S.A.  3.75     70.0  Dominican Republic                 7
# 56        U.S.A.  4.00     70.0             Ecuador                 7
# 57        U.S.A.  3.00     70.0           Venezuela                 7
# 58        U.S.A.  3.00     70.0           Venezuela                 7
# 59        U.S.A.  2.75     70.0           Indonesia                 7
# 60        U.S.A.  3.50     70.0          Madagascar                 7
# 61        U.S.A.  3.00     70.0           Venezuela                 7
# 62        U.S.A.  3.75     70.0           Venezuela                 7
# 63         Spain  3.00     70.0               Ghana                 6
# 64         Spain  2.75     70.0             Ecuador                 6
# 65         Spain  2.75     85.0             Ecuador                 6
# ..           ...   ...      ...                 ...               ...
# 69        Canada  3.00     64.0              Belize                 1
# 70        Canada  3.25     66.0          Madagascar                 1
# 71        Canada  3.25     75.0  Dominican Republic                 1
# 72        Canada  3.25     63.0    Papua New Guinea                 1
# 73        Canada  3.25     70.0           Venezuela                 1
# 74        Canada  3.50     68.0                Peru                 1
# 75         Italy  3.75     70.0                Peru                 3
# 76         Italy  4.00     70.0           Venezuela                 3
# 78         Italy  5.00     70.0           Venezuela                 3
# 79         Italy  3.00     70.0             Ecuador                 3
# 80         Italy  3.00     70.0             Jamaica                 3
# 81         Italy  3.50     70.0             Grenada                 3
# 82         Italy  3.75     70.0           Venezuela                 3
# 83         Italy  4.00     70.0          Madagascar                 3
# 84         Italy  3.50     70.0            Trinidad                 3
# 88        Brazil  3.25     75.0              Brazil                 0
# 89        Brazil  2.75     85.0              Brazil                 0
# 90        Brazil  3.75     50.0              Brazil                 0
# 91        Brazil  3.75     75.0              Brazil                 0
# 92        Brazil  4.00     60.0              Brazil                 0
# 93        U.S.A.  3.00     75.0  Dominican Republic                 7
# 94        U.S.A.  3.50     75.0             Bolivia                 7
# 95        France  3.00     75.0          Madagascar                 2
# 96        France  2.50     72.0              Mexico                 2
# 97        France  2.75     75.0             Ecuador                 2
# 98        France  3.00     75.0           Venezuela                 2
# 99        U.S.A.  3.50     70.0            Trinidad                 7
# 100       U.S.A.  3.75     70.0            Tanzania                 7
# 101       U.S.A.  3.50     73.0             Vietnam                 7
# 102       U.S.A.  3.25     70.0             Ecuador                 7
#
#      bean_orig_code
# 36               17
# 37                9
# 38               16
# 39               13
# 40                4
# 41               11
# 42               17
# 43               14
# 44               11
# 45               13
# 46                1
# 47               13
# 48                4
# 49               16
# 50                3
# 51                1
# 52                1
# 53               13
# 54               12
# 55                3
# 56                4
# 57               16
# 58               16
# 59                7
# 60                9
# 61               16
# 62               16
# 63                5
# 64                4
# 65                4
# ..              ...
# 69                0
# 70                9
# 71                3
# 72               12
# 73               16
# 74               13
# 75               13
# 76               16
# 78               16
# 79                4
# 80                8
# 81                6
# 82               16
# 83                9
# 84               15
# 88                2
# 89                2
# 90                2
# 91                2
# 92                2
# 93                3
# 94                1
# 95                9
# 96               10
# 97                4
# 98               16
# 99               15
# 100              14
# 101              17
# 102               4
#
# [63 rows x 6 columns]>

# %% [markdown]
# Определите, где растут лучшие какао бобы, вычислив средний значение и медиану рейтинга батончика для каждого места происхождения. Напишите первую тройку лучших в обоих случаях.

# %%
#best_bar.bean_orig.unique()
best_bar.groupby(best_bar.bean_orig).rate.mean().nlargest(3)
# Out:
# bean_orig
# Papua New Guinea    3.625
# Tanzania            3.625
# Brazil              3.500
# Name: rate, dtype: float64

# %%
best_bar.groupby(best_bar.bean_orig).rate.median().nlargest(3)
# Out:
# bean_orig
# Brazil              3.750
# Papua New Guinea    3.625
# Tanzania            3.625
# Name: rate, dtype: float64

# %%
best_bar.groupby(best_bar.company_loc).rate.mean().nlargest(3) #omg
# Out:
# company_loc
# Italy          3.722222
# Brazil         3.500000
# Netherlands    3.500000
# Name: rate, dtype: float64

# %%
best_bar.groupby(best_bar.company_loc).rate.median().nlargest(3)
# Out:
# company_loc
# Brazil         3.75
# Italy          3.75
# Netherlands    3.50
# Name: rate, dtype: float64

# %% [markdown]
# Определите, где производят лучшие батончики, вычислив средний значение и медиану рейтинга батончика для каждого места происхождения.
